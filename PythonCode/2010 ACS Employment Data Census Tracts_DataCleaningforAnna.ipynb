# %%
import pandas as pd

# %%
data2010ACSEmploymentCensusTractfile = r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\2010ACSEmploymentDataCensusTracts.csv'

# %%
data2010ACSEmploymentCensusTractall = pd.read_csv(data2010ACSEmploymentCensusTractfile)

# %%
data2010ACSEmploymentCensusTractall.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 2  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 3  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 4  1400000US06085500400  Census Tract 5004, Santa Clara County, California
#
#                                   S2301_C01_001E  \
# 0  Total!!Estimate!!Population 16 years and over
# 1                                           4796
# 2                                           5092
# 3                                           3264
# 4                                           1932
#
#                                       S2301_C01_001M  \
# 0  Total!!Margin of Error!!Population 16 years an...
# 1                                                540
# ...

# %%
ACSEmployment =  pd.read_csv(data2010ACSEmploymentCensusTractfile, skiprows=[0])

# %%
ACSEmployment.shape
# Out:
# (372, 242)

# %%
for col in ACSEmployment.columns:
    print(col)
# Out:
# Geography
# Geographic Area Name
# Total!!Estimate!!Population 16 years and over
# Total!!Margin of Error!!Population 16 years and over
# In labor force!!Estimate!!Population 16 years and over
# In labor force!!Margin of Error!!Population 16 years and over
# Employed!!Estimate!!Population 16 years and over
# Employed!!Margin of Error!!Population 16 years and over
# Unemployment rate!!Estimate!!Population 16 years and over
# Unemployment rate!!Margin of Error!!Population 16 years and over
# Total!!Estimate!!AGE!!16 to 19 years
# Total!!Margin of Error!!AGE!!16 to 19 years
# In labor force!!Estimate!!AGE!!16 to 19 years
# In labor force!!Margin of Error!!AGE!!16 to 19 years
# Employed!!Estimate!!AGE!!16 to 19 years
# Employed!!Margin of Error!!AGE!!16 to 19 years
# Unemployment rate!!Estimate!!AGE!!16 to 19 years
# Unemployment rate!!Margin of Error!!AGE!!16 to 19 years
# Total!!Estimate!!AGE!!20 to 24 years
# Total!!Margin of Error!!AGE!!20 to 24 years
# ...

# %%
ACSEmployment_cleaned = ACSEmployment.drop(columns=[col for col in ACSEmployment.columns if 'Margin of Error'in col])

# %%
ACSEmployment_cleaned.shape
# Out:
# (372, 122)

# %%
for col in ACSEmployment_cleaned.columns:
    print(col)
# Out:
# Geography
# Geographic Area Name
# Total!!Estimate!!Population 16 years and over
# In labor force!!Estimate!!Population 16 years and over
# Employed!!Estimate!!Population 16 years and over
# Unemployment rate!!Estimate!!Population 16 years and over
# Total!!Estimate!!AGE!!16 to 19 years
# In labor force!!Estimate!!AGE!!16 to 19 years
# Employed!!Estimate!!AGE!!16 to 19 years
# Unemployment rate!!Estimate!!AGE!!16 to 19 years
# Total!!Estimate!!AGE!!20 to 24 years
# In labor force!!Estimate!!AGE!!20 to 24 years
# Employed!!Estimate!!AGE!!20 to 24 years
# Unemployment rate!!Estimate!!AGE!!20 to 24 years
# Total!!Estimate!!AGE!!25 to 44 years
# In labor force!!Estimate!!AGE!!25 to 44 years
# Employed!!Estimate!!AGE!!25 to 44 years
# Unemployment rate!!Estimate!!AGE!!25 to 44 years
# Total!!Estimate!!AGE!!45 to 54 years
# In labor force!!Estimate!!AGE!!45 to 54 years
# Employed!!Estimate!!AGE!!45 to 54 years
# Unemployment rate!!Estimate!!AGE!!45 to 54 years
# ...

# %%
data2010ACSEmploymentCensusTract = pd.read_csv(data2010ACSEmploymentCensusTractfile, skiprows=[1])

# %%
data2010ACSEmploymentCensusTract.shape
# Out:
# (372, 242)

# %%
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S2301_C01_001E  S2301_C01_001M  S2301_C02_001E  S2301_C02_001M  \
# 0            4796             540            77.1             3.8
# 1            5092             386            52.7             7.1
# 2            3264             942            74.4             8.8
# 3            1932             195            64.7             7.0
# 4            4181             299            67.8             4.8
#
#    S2301_C03_001E  S2301_C03_001M  S2301_C04_001E  S2301_C04_001M  ...  \
# ...

# %%
#Checking for number of columns
data2010ACSEmploymentCensusTract.columns
# Out:
# Index(['GEO_ID', 'NAME', 'S2301_C01_001E', 'S2301_C01_001M', 'S2301_C02_001E',
#        'S2301_C02_001M', 'S2301_C03_001E', 'S2301_C03_001M', 'S2301_C04_001E',
#        'S2301_C04_001M',
#        ...
#        'S2301_C04_029E', 'S2301_C04_029M', 'S2301_C01_030E', 'S2301_C01_030M',
#        'S2301_C02_030E', 'S2301_C02_030M', 'S2301_C03_030E', 'S2301_C03_030M',
#        'S2301_C04_030E', 'S2301_C04_030M'],
#       dtype='object', length=242)

# %%
#Rename the column "NAME" to "NAMESLSAD10"
data2010ACSEmploymentCensusTract.rename(columns={"NAME":"NAMESLSAD10"}, inplace=True)

# %%
ACSEmployment_cleaned.head()
# Out:
#               Geography                               Geographic Area Name  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    Total!!Estimate!!Population 16 years and over  \
# 0                                           4796
# 1                                           5092
# 2                                           3264
# 3                                           1932
# 4                                           4181
#
#    In labor force!!Estimate!!Population 16 years and over  \
# 0                                               77.1
# 1                                               52.7
# ...

# %%
ACSEmployment_cleaned.rename(columns={"Geographic Area Name":"NAMESLSAD10"}, inplace=True)

# %%
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                        NAMESLSAD10  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S2301_C01_001E  S2301_C01_001M  S2301_C02_001E  S2301_C02_001M  \
# 0            4796             540            77.1             3.8
# 1            5092             386            52.7             7.1
# 2            3264             942            74.4             8.8
# 3            1932             195            64.7             7.0
# 4            4181             299            67.8             4.8
#
#    S2301_C03_001E  S2301_C03_001M  S2301_C04_001E  S2301_C04_001M  ...  \
# ...

# %%
pd.set_option('display.max_rows',500)

# %%
# Confirm the change
data2010ACSEmploymentCensusTract.columns
# Out:
# Index(['GEO_ID', 'NAMESLSAD10', 'S2301_C01_001E', 'S2301_C01_001M',
#        'S2301_C02_001E', 'S2301_C02_001M', 'S2301_C03_001E', 'S2301_C03_001M',
#        'S2301_C04_001E', 'S2301_C04_001M',
#        ...
#        'S2301_C04_029E', 'S2301_C04_029M', 'S2301_C01_030E', 'S2301_C01_030M',
#        'S2301_C02_030E', 'S2301_C02_030M', 'S2301_C03_030E', 'S2301_C03_030M',
#        'S2301_C04_030E', 'S2301_C04_030M'],
#       dtype='object', length=242)

# %%
for col in data2010ACSEmploymentCensusTract.columns:
    print(col)
# Out:
# GEO_ID
# NAMESLSAD10
# S2301_C01_001E
# S2301_C01_001M
# S2301_C02_001E
# S2301_C02_001M
# S2301_C03_001E
# S2301_C03_001M
# S2301_C04_001E
# S2301_C04_001M
# S2301_C01_002E
# S2301_C01_002M
# S2301_C02_002E
# S2301_C02_002M
# S2301_C03_002E
# S2301_C03_002M
# S2301_C04_002E
# S2301_C04_002M
# S2301_C01_003E
# S2301_C01_003M
# S2301_C02_003E
# S2301_C02_003M
# S2301_C03_003E
# S2301_C03_003M
# S2301_C04_003E
# S2301_C04_003M
# S2301_C01_004E
# S2301_C01_004M
# S2301_C02_004E
# S2301_C02_004M
# S2301_C03_004E
# S2301_C03_004M
# S2301_C04_004E
# S2301_C04_004M
# S2301_C01_005E
# S2301_C01_005M
# S2301_C02_005E
# S2301_C02_005M
# S2301_C03_005E
# S2301_C03_005M
# S2301_C04_005E
# S2301_C04_005M
# S2301_C01_006E
# S2301_C01_006M
# S2301_C02_006E
# S2301_C02_006M
# S2301_C03_006E
# S2301_C03_006M
# S2301_C04_006E
# S2301_C04_006M
# S2301_C01_007E
# S2301_C01_007M
# S2301_C02_007E
# S2301_C02_007M
# S2301_C03_007E
# S2301_C03_007M
# S2301_C04_007E
# S2301_C04_007M
# S2301_C01_008E
# ...

# %%
# View the cleaned column names
print(data2010ACSEmploymentCensusTract.columns)
# Out:
# Index(['GEO_ID', 'NAMESLSAD10', 'S2301_C01_001E', 'S2301_C01_001M',
#        'S2301_C02_001E', 'S2301_C02_001M', 'S2301_C03_001E', 'S2301_C03_001M',
#        'S2301_C04_001E', 'S2301_C04_001M',
#        ...
#        'S2301_C04_029E', 'S2301_C04_029M', 'S2301_C01_030E', 'S2301_C01_030M',
#        'S2301_C02_030E', 'S2301_C02_030M', 'S2301_C03_030E', 'S2301_C03_030M',
#        'S2301_C04_030E', 'S2301_C04_030M'],
#       dtype='object', length=242)

# %%
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                        NAMESLSAD10  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S2301_C01_001E  S2301_C01_001M  S2301_C02_001E  S2301_C02_001M  \
# 0            4796             540            77.1             3.8
# 1            5092             386            52.7             7.1
# 2            3264             942            74.4             8.8
# 3            1932             195            64.7             7.0
# 4            4181             299            67.8             4.8
#
#    S2301_C03_001E  S2301_C03_001M  S2301_C04_001E  S2301_C04_001M  ...  \
# ...

# %%
data2010ACSEmploymentCensusTract.shape
# Out:
# (372, 242)

# %%
data2010ACSEmploymentCensusTract
# Out:
#                    GEO_ID                                        NAMESLSAD10  \
# 0    1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1    1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2    1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3    1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4    1400000US06085500500  Census Tract 5005, Santa Clara County, California
# 5    1400000US06085500600  Census Tract 5006, Santa Clara County, California
# 6    1400000US06085500800  Census Tract 5008, Santa Clara County, California
# 7    1400000US06085500901  Census Tract 5009.01, Santa Clara County, Cali...
# 8    1400000US06085500902  Census Tract 5009.02, Santa Clara County, Cali...
# 9    1400000US06085501000  Census Tract 5010, Santa Clara County, California
# 10   1400000US06085501101  Census Tract 5011.01, Santa Clara County, Cali...
# ...

# %%
data2010ACSEmploymentCensusTract["NAMESLSAD10"] = data2010ACSEmploymentCensusTract["NAMESLSAD10"].str.split(',', n=1).str[0]

# %%
ACSEmployment_cleaned["NAMESLSAD10"] = ACSEmployment_cleaned["NAMESLSAD10"].str.split(',', n=1).str[0]

# %%
ACSEmployment_cleaned.head()
# Out:
#               Geography        NAMESLSAD10  \
# 0  1400000US06085500100  Census Tract 5001
# 1  1400000US06085500200  Census Tract 5002
# 2  1400000US06085500300  Census Tract 5003
# 3  1400000US06085500400  Census Tract 5004
# 4  1400000US06085500500  Census Tract 5005
#
#    Total!!Estimate!!Population 16 years and over  \
# 0                                           4796
# 1                                           5092
# 2                                           3264
# 3                                           1932
# 4                                           4181
#
#    In labor force!!Estimate!!Population 16 years and over  \
# 0                                               77.1
# 1                                               52.7
# 2                                               74.4
# 3                                               64.7
# 4                                               67.8
#
#    Employed!!Estimate!!Population 16 years and over  \
# ...

# %%
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID        NAMESLSAD10  S2301_C01_001E  S2301_C01_001M  \
# 0  1400000US06085500100  Census Tract 5001            4796             540
# 1  1400000US06085500200  Census Tract 5002            5092             386
# 2  1400000US06085500300  Census Tract 5003            3264             942
# 3  1400000US06085500400  Census Tract 5004            1932             195
# 4  1400000US06085500500  Census Tract 5005            4181             299
#
#    S2301_C02_001E  S2301_C02_001M  S2301_C03_001E  S2301_C03_001M  \
# 0            77.1             3.8            70.3             4.2
# 1            52.7             7.1            50.8             7.0
# 2            74.4             8.8            62.0            16.3
# 3            64.7             7.0            60.7             7.4
# 4            67.8             4.8            64.1             5.3
#
#    S2301_C04_001E  S2301_C04_001M  ...  S2301_C04_029E  S2301_C04_029M  \
# ...

# %%
for col in data2010ACSEmploymentCensusTract.columns:
    print(col)
# Out:
# GEO_ID
# NAMESLSAD10
# S2301_C01_001E
# S2301_C01_001M
# S2301_C02_001E
# S2301_C02_001M
# S2301_C03_001E
# S2301_C03_001M
# S2301_C04_001E
# S2301_C04_001M
# S2301_C01_002E
# S2301_C01_002M
# S2301_C02_002E
# S2301_C02_002M
# S2301_C03_002E
# S2301_C03_002M
# S2301_C04_002E
# S2301_C04_002M
# S2301_C01_003E
# S2301_C01_003M
# S2301_C02_003E
# S2301_C02_003M
# S2301_C03_003E
# S2301_C03_003M
# S2301_C04_003E
# S2301_C04_003M
# S2301_C01_004E
# S2301_C01_004M
# S2301_C02_004E
# S2301_C02_004M
# S2301_C03_004E
# S2301_C03_004M
# S2301_C04_004E
# S2301_C04_004M
# S2301_C01_005E
# S2301_C01_005M
# S2301_C02_005E
# S2301_C02_005M
# S2301_C03_005E
# S2301_C03_005M
# S2301_C04_005E
# S2301_C04_005M
# S2301_C01_006E
# S2301_C01_006M
# S2301_C02_006E
# S2301_C02_006M
# S2301_C03_006E
# S2301_C03_006M
# S2301_C04_006E
# S2301_C04_006M
# S2301_C01_007E
# S2301_C01_007M
# S2301_C02_007E
# S2301_C02_007M
# S2301_C03_007E
# S2301_C03_007M
# S2301_C04_007E
# S2301_C04_007M
# S2301_C01_008E
# ...

# %%
data2010ACSEmploymentCensusTract.shape
# Out:
# (372, 242)

# %%
data2010ACSEmploymentCensusTract.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\Employment_Census_Tract_Row_CLEAN.csv')

# %%
for col in ACSEmployment_cleaned.columns:
    print(col)
# Out:
# Geography
# NAMESLSAD10
# Total!!Estimate!!Population 16 years and over
# In labor force!!Estimate!!Population 16 years and over
# Employed!!Estimate!!Population 16 years and over
# Unemployment rate!!Estimate!!Population 16 years and over
# Total!!Estimate!!AGE!!16 to 19 years
# In labor force!!Estimate!!AGE!!16 to 19 years
# Employed!!Estimate!!AGE!!16 to 19 years
# Unemployment rate!!Estimate!!AGE!!16 to 19 years
# Total!!Estimate!!AGE!!20 to 24 years
# In labor force!!Estimate!!AGE!!20 to 24 years
# Employed!!Estimate!!AGE!!20 to 24 years
# Unemployment rate!!Estimate!!AGE!!20 to 24 years
# Total!!Estimate!!AGE!!25 to 44 years
# In labor force!!Estimate!!AGE!!25 to 44 years
# Employed!!Estimate!!AGE!!25 to 44 years
# Unemployment rate!!Estimate!!AGE!!25 to 44 years
# Total!!Estimate!!AGE!!45 to 54 years
# In labor force!!Estimate!!AGE!!45 to 54 years
# Employed!!Estimate!!AGE!!45 to 54 years
# Unemployment rate!!Estimate!!AGE!!45 to 54 years
# ...

# %%
ACSEmployment_cleaned.columns = ACSEmployment_cleaned.columns.str.replace('Estimate!!','',regex=False)

# %%
for col in ACSEmployment_cleaned.columns:
    print(col)
# Out:
# Geography
# NAMESLSAD10
# Total!!Population 16 years and over
# In labor force!!Population 16 years and over
# Employed!!Population 16 years and over
# Unemployment rate!!Population 16 years and over
# Total!!AGE!!16 to 19 years
# In labor force!!AGE!!16 to 19 years
# Employed!!AGE!!16 to 19 years
# Unemployment rate!!AGE!!16 to 19 years
# Total!!AGE!!20 to 24 years
# In labor force!!AGE!!20 to 24 years
# Employed!!AGE!!20 to 24 years
# Unemployment rate!!AGE!!20 to 24 years
# Total!!AGE!!25 to 44 years
# In labor force!!AGE!!25 to 44 years
# Employed!!AGE!!25 to 44 years
# Unemployment rate!!AGE!!25 to 44 years
# Total!!AGE!!45 to 54 years
# In labor force!!AGE!!45 to 54 years
# Employed!!AGE!!45 to 54 years
# Unemployment rate!!AGE!!45 to 54 years
# Total!!AGE!!55 to 64 years
# In labor force!!AGE!!55 to 64 years
# Employed!!AGE!!55 to 64 years
# Unemployment rate!!AGE!!55 to 64 years
# Total!!AGE!!65 to 74 years
# In labor force!!AGE!!65 to 74 years
# ...

# %%
ACSEmployment_cleaned.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\Employment_Census_Tract_Row_CLEAN20241013.csv')

# %%
#To check for the mssing values
data2010ACSEmploymentCensusTract.isnull().sum()
# Out:
# GEO_ID            0
# NAMESLSAD10       0
# S2301_C01_001E    0
# S2301_C01_001M    0
# S2301_C02_001E    0
#                  ..
# S2301_C02_030M    0
# S2301_C03_030E    0
# S2301_C03_030M    0
# S2301_C04_030E    0
# S2301_C04_030M    0
# Length: 242, dtype: int64

# %%
#
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                        NAMESLSAD10  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 2  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 3  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 4  1400000US06085500400  Census Tract 5004, Santa Clara County, California
#
#                                   S2301_C01_001E  \
# 0  Total!!Estimate!!Population 16 years and over
# 1                                           4796
# 2                                           5092
# 3                                           3264
# 4                                           1932
#
#                                       S2301_C01_001M  \
# 0  Total!!Margin of Error!!Population 16 years an...
# 1                                                540
# ...
