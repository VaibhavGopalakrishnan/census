# %%
import pandas as pd

# %%
ACSIncomeCensusTract2010file = r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\ACSIncomeCensusTract2010.csv'

# %%
dataACSIncomeCensusTract2010all = pd.read_csv(ACSIncomeCensusTract2010file)

# %%
dataACSIncomeCensusTract2010all.shape
# Out:
# (373, 122)

# %%
dataACSIncomeCensusTract2010all.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 2  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 3  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 4  1400000US06085500400  Census Tract 5004, Santa Clara County, California
#
#                 S1903_C01_001E                      S1903_C01_001M  \
# 0  Total!!Estimate!!Households  Total!!Margin of Error!!Households
# 1                         1970                                 103
# 2                         2023                                 101
# 3                         1204                                  75
# 4                          986                                  76
#
#                                   S1903_C02_001E  \
# 0  Median income (dollars)!!Estimate!!Households
# ...

# %%
ACSIncome =  pd.read_csv(ACSIncomeCensusTract2010file, skiprows=[0])

# %%
ACSIncome.shape
# Out:
# (372, 122)

# %%
for col in ACSIncome.columns:
    print(col)
# Out:
# Geography
# Geographic Area Name
# Total!!Estimate!!Households
# Total!!Margin of Error!!Households
# Median income (dollars)!!Estimate!!Households
# Median income (dollars)!!Margin of Error!!Households
# Total!!Estimate!!One race!!White
# Total!!Margin of Error!!One race!!White
# Median income (dollars)!!Estimate!!One race!!White
# Median income (dollars)!!Margin of Error!!One race!!White
# Total!!Estimate!!One race!!Black or African American
# Total!!Margin of Error!!One race!!Black or African American
# Median income (dollars)!!Estimate!!One race!!Black or African American
# Median income (dollars)!!Margin of Error!!One race!!Black or African American
# Total!!Estimate!!One race!!American Indian and Alaska Native
# Total!!Margin of Error!!One race!!American Indian and Alaska Native
# Median income (dollars)!!Estimate!!One race!!American Indian and Alaska Native
# Median income (dollars)!!Margin of Error!!One race!!American Indian and Alaska Native
# ...

# %%
ACSIncome_cleaned = ACSIncome.drop(columns=[col for col in ACSIncome.columns if 'Margin of Error'in col])

# %%
ACSIncome_cleaned.shape
# Out:
# (372, 62)

# %%
dataACSIncomeCensusTract2010.shape
# Out:
# (372, 122)

# %%
for col in ACSIncome_cleaned.columns:
    print(col)
# Out:
# Geography
# Geographic Area Name
# Total!!Estimate!!Households
# Median income (dollars)!!Estimate!!Households
# Total!!Estimate!!One race!!White
# Median income (dollars)!!Estimate!!One race!!White
# Total!!Estimate!!One race!!Black or African American
# Median income (dollars)!!Estimate!!One race!!Black or African American
# Total!!Estimate!!One race!!American Indian and Alaska Native
# Median income (dollars)!!Estimate!!One race!!American Indian and Alaska Native
# Total!!Estimate!!One race!!Asian
# Median income (dollars)!!Estimate!!One race!!Asian
# Total!!Estimate!!One race!!Native Hawaiian and Other Pacific Islander
# Median income (dollars)!!Estimate!!One race!!Native Hawaiian and Other Pacific Islander
# Total!!Estimate!!One race!!Some other race
# Median income (dollars)!!Estimate!!One race!!Some other race
# Total!!Estimate!!Two or more races
# Median income (dollars)!!Estimate!!Two or more races
# Total!!Estimate!!Hispanic or Latino origin (of any race)
# ...

# %%
ACSIncome_cleaned.rename(columns={"Geographic Area Name":"NAMESLSAD10"}, inplace=True)

# %%
ACSIncome_cleaned.head()
# Out:
#               Geography                                        NAMESLSAD10  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    Total!!Estimate!!Households Median income (dollars)!!Estimate!!Households  \
# 0                         1970                                         60259
# 1                         2023                                         71010
# 2                         1204                                         96250
# 3                          986                                         60000
# 4                         1864                                        121667
#
#    Total!!Estimate!!One race!!White  \
# ...

# %%
ACSIncome_cleaned["NAMESLSAD10"] = ACSIncome_cleaned["NAMESLSAD10"].str.split(',', n=1).str[0]

# %%
ACSIncome_cleaned.head()
# Out:
#               Geography        NAMESLSAD10  Total!!Estimate!!Households  \
# 0  1400000US06085500100  Census Tract 5001                         1970
# 1  1400000US06085500200  Census Tract 5002                         2023
# 2  1400000US06085500300  Census Tract 5003                         1204
# 3  1400000US06085500400  Census Tract 5004                          986
# 4  1400000US06085500500  Census Tract 5005                         1864
#
#   Median income (dollars)!!Estimate!!Households  \
# 0                                         60259
# 1                                         71010
# 2                                         96250
# 3                                         60000
# 4                                        121667
#
#    Total!!Estimate!!One race!!White  \
# 0                              38.5
# 1                              66.1
# 2                              63.9
# 3                              67.2
# 4                              80.7
#
# ...

# %%
ACSIncome_cleaned.columns = ACSIncome_cleaned.columns.str.replace('Estimate!!','',regex=False)

# %%
for col in ACSIncome_cleaned.columns:
    print(col)
# Out:
# Geography
# NAMESLSAD10
# Total!!Households
# Median income (dollars)!!Households
# Total!!One race!!White
# Median income (dollars)!!One race!!White
# Total!!One race!!Black or African American
# Median income (dollars)!!One race!!Black or African American
# Total!!One race!!American Indian and Alaska Native
# Median income (dollars)!!One race!!American Indian and Alaska Native
# Total!!One race!!Asian
# Median income (dollars)!!One race!!Asian
# Total!!One race!!Native Hawaiian and Other Pacific Islander
# Median income (dollars)!!One race!!Native Hawaiian and Other Pacific Islander
# Total!!One race!!Some other race
# Median income (dollars)!!One race!!Some other race
# Total!!Two or more races
# Median income (dollars)!!Two or more races
# Total!!Hispanic or Latino origin (of any race)
# Median income (dollars)!!Hispanic or Latino origin (of any race)
# Total!!White alone, not Hispanic or Latino
# Median income (dollars)!!White alone, not Hispanic or Latino
# ...

# %%
dataACSIncomeCensusTract2010 = pd.read_csv(ACSIncomeCensusTract2010file, skiprows=[1])

# %%
dataACSIncomeCensusTract2010.shape
# Out:
# (372, 122)

# %%
dataACSIncomeCensusTract2010.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S1903_C01_001E  S1903_C01_001M S1903_C02_001E  S1903_C02_001M  \
# 0            1970             103          60259           10751
# 1            2023             101          71010           12810
# 2            1204              75          96250           20705
# 3             986              76          60000           10255
# 4            1864              93         121667           27083
#
#    S1903_C01_002E  S1903_C01_002M  S1903_C02_002E  S1903_C02_002M  ...  \
# ...

# %%
#Checking for number of columns
dataACSIncomeCensusTract2010.columns
# Out:
# Index(['GEO_ID', 'NAME', 'S1903_C01_001E', 'S1903_C01_001M', 'S1903_C02_001E',
#        'S1903_C02_001M', 'S1903_C01_002E', 'S1903_C01_002M', 'S1903_C02_002E',
#        'S1903_C02_002M',
#        ...
#        'S1903_C02_029E', 'S1903_C02_029M', 'S1903_C01_030E', 'S1903_C01_030M',
#        'S1903_C02_030E', 'S1903_C02_030M', 'S1903_C01_031E', 'S1903_C01_031M',
#        'S1903_C02_031E', 'S1903_C02_031M'],
#       dtype='object', length=122)

# %%
#Rename the column "NAME" to "NAMESLSAD10"
dataACSIncomeCensusTract2010.rename(columns={"NAME":"NAMESLSAD10"}, inplace=True)

# %%
ACSIncome_cleaned.head()
# Out:
#               Geography                               Geographic Area Name  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    Total!!Estimate!!Households Median income (dollars)!!Estimate!!Households  \
# 0                         1970                                         60259
# 1                         2023                                         71010
# 2                         1204                                         96250
# 3                          986                                         60000
# 4                         1864                                        121667
#
#    Total!!Estimate!!One race!!White  \
# ...

# %%
ACSIncome_cleaned.rename(columns={"Geographic Area Name":"NAMESLSAD10"}, inplace=True)

# %%
dataACSIncomeCensusTract2010.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S1903_C01_001E  S1903_C01_001M S1903_C02_001E  S1903_C02_001M  \
# 0            1970             103          60259           10751
# 1            2023             101          71010           12810
# 2            1204              75          96250           20705
# 3             986              76          60000           10255
# 4            1864              93         121667           27083
#
#    S1903_C01_002E  S1903_C01_002M  S1903_C02_002E  S1903_C02_002M  ...  \
# ...

# %%
for col in dataACSIncomeCensusTract2010.columns:
    print(col)
# Out:
# GEO_ID
# NAMESLSAD10
# S1903_C01_001E
# S1903_C01_001M
# S1903_C02_001E
# S1903_C02_001M
# S1903_C01_002E
# S1903_C01_002M
# S1903_C02_002E
# S1903_C02_002M
# S1903_C01_003E
# S1903_C01_003M
# S1903_C02_003E
# S1903_C02_003M
# S1903_C01_004E
# S1903_C01_004M
# S1903_C02_004E
# S1903_C02_004M
# S1903_C01_005E
# S1903_C01_005M
# S1903_C02_005E
# S1903_C02_005M
# S1903_C01_006E
# S1903_C01_006M
# S1903_C02_006E
# S1903_C02_006M
# S1903_C01_007E
# S1903_C01_007M
# S1903_C02_007E
# S1903_C02_007M
# S1903_C01_008E
# S1903_C01_008M
# S1903_C02_008E
# S1903_C02_008M
# S1903_C01_009E
# S1903_C01_009M
# S1903_C02_009E
# S1903_C02_009M
# S1903_C01_010E
# S1903_C01_010M
# S1903_C02_010E
# S1903_C02_010M
# S1903_C01_012E
# S1903_C01_012M
# S1903_C02_012E
# S1903_C02_012M
# S1903_C01_013E
# S1903_C01_013M
# S1903_C02_013E
# S1903_C02_013M
# S1903_C01_014E
# S1903_C01_014M
# S1903_C02_014E
# S1903_C02_014M
# S1903_C01_015E
# S1903_C01_015M
# S1903_C02_015E
# S1903_C02_015M
# S1903_C01_016E
# ...

# %%
# View the cleaned column names
print(dataACSIncomeCensusTract2010.columns)
# Out:
# Index(['GEO_ID', 'NAMESLSAD10', 'S1903_C01_001E', 'S1903_C01_001M',
#        'S1903_C02_001E', 'S1903_C02_001M', 'S1903_C01_002E', 'S1903_C01_002M',
#        'S1903_C02_002E', 'S1903_C02_002M',
#        ...
#        'S1903_C02_029E', 'S1903_C02_029M', 'S1903_C01_030E', 'S1903_C01_030M',
#        'S1903_C02_030E', 'S1903_C02_030M', 'S1903_C01_031E', 'S1903_C01_031M',
#        'S1903_C02_031E', 'S1903_C02_031M'],
#       dtype='object', length=122)

# %%
dataACSIncomeCensusTract2010.head()
# Out:
#                  GEO_ID                                        NAMESLSAD10  \
# 0  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3  1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4  1400000US06085500500  Census Tract 5005, Santa Clara County, California
#
#    S1903_C01_001E  S1903_C01_001M S1903_C02_001E  S1903_C02_001M  \
# 0            1970             103          60259           10751
# 1            2023             101          71010           12810
# 2            1204              75          96250           20705
# 3             986              76          60000           10255
# 4            1864              93         121667           27083
#
#    S1903_C01_002E  S1903_C01_002M  S1903_C02_002E  S1903_C02_002M  ...  \
# ...

# %%
dataACSIncomeCensusTract2010.shape
# Out:
# (372, 122)

# %%
dataACSIncomeCensusTract2010
# Out:
#                    GEO_ID                                        NAMESLSAD10  \
# 0    1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 1    1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 2    1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 3    1400000US06085500400  Census Tract 5004, Santa Clara County, California
# 4    1400000US06085500500  Census Tract 5005, Santa Clara County, California
# 5    1400000US06085500600  Census Tract 5006, Santa Clara County, California
# 6    1400000US06085500800  Census Tract 5008, Santa Clara County, California
# 7    1400000US06085500901  Census Tract 5009.01, Santa Clara County, Cali...
# 8    1400000US06085500902  Census Tract 5009.02, Santa Clara County, Cali...
# 9    1400000US06085501000  Census Tract 5010, Santa Clara County, California
# 10   1400000US06085501101  Census Tract 5011.01, Santa Clara County, Cali...
# ...

# %%
dataACSIncomeCensusTract2010["NAMESLSAD10"] = dataACSIncomeCensusTract2010["NAMESLSAD10"].str.split(',', n=1).str[0]

# %%
dataACSIncomeCensusTract2010.head()
# Out:
#                  GEO_ID        NAMESLSAD10  S1903_C01_001E  S1903_C01_001M  \
# 0  1400000US06085500100  Census Tract 5001            1970             103
# 1  1400000US06085500200  Census Tract 5002            2023             101
# 2  1400000US06085500300  Census Tract 5003            1204              75
# 3  1400000US06085500400  Census Tract 5004             986              76
# 4  1400000US06085500500  Census Tract 5005            1864              93
#
#   S1903_C02_001E  S1903_C02_001M  S1903_C01_002E  S1903_C01_002M  \
# 0          60259           10751            38.5             6.3
# 1          71010           12810            66.1             7.2
# 2          96250           20705            63.9             8.0
# 3          60000           10255            67.2             9.3
# 4         121667           27083            80.7             5.9
#
#    S1903_C02_002E  S1903_C02_002M  ...  S1903_C02_029E  S1903_C02_029M  \
# ...

# %%
for col in dataACSIncomeCensusTract2010.columns:
    print(col)
# Out:
# GEO_ID
# NAMESLSAD10
# S1903_C01_001E
# S1903_C01_001M
# S1903_C02_001E
# S1903_C02_001M
# S1903_C01_002E
# S1903_C01_002M
# S1903_C02_002E
# S1903_C02_002M
# S1903_C01_003E
# S1903_C01_003M
# S1903_C02_003E
# S1903_C02_003M
# S1903_C01_004E
# S1903_C01_004M
# S1903_C02_004E
# S1903_C02_004M
# S1903_C01_005E
# S1903_C01_005M
# S1903_C02_005E
# S1903_C02_005M
# S1903_C01_006E
# S1903_C01_006M
# S1903_C02_006E
# S1903_C02_006M
# S1903_C01_007E
# S1903_C01_007M
# S1903_C02_007E
# S1903_C02_007M
# S1903_C01_008E
# S1903_C01_008M
# S1903_C02_008E
# S1903_C02_008M
# S1903_C01_009E
# S1903_C01_009M
# S1903_C02_009E
# S1903_C02_009M
# S1903_C01_010E
# S1903_C01_010M
# S1903_C02_010E
# S1903_C02_010M
# S1903_C01_012E
# S1903_C01_012M
# S1903_C02_012E
# S1903_C02_012M
# S1903_C01_013E
# S1903_C01_013M
# S1903_C02_013E
# S1903_C02_013M
# S1903_C01_014E
# S1903_C01_014M
# S1903_C02_014E
# S1903_C02_014M
# S1903_C01_015E
# S1903_C01_015M
# S1903_C02_015E
# S1903_C02_015M
# S1903_C01_016E
# ...

# %%
dataACSIncomeCensusTract2010.shape
# Out:
# (372, 122)

# %%
dataACSIncomeCensusTract2010.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\Income_Census_Tract_Row_CLEAN.csv')

# %%
ACSIncome_cleaned.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\Income_Census_Tract_Row_CLEAN20241013.csv')
