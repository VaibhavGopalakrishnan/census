# %%
import pandas as pd

# %%
data2010ACSIncomeCensusTractfile = r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\AssignedData\2010ACSEmploymentDataCensusTracts.csv'

# %%
data2010ACSEmploymentCensusTract = pd.read_csv(data2010ACSEmploymentCensusTractfile)

# %%
data2010ACSEmploymentCensusTract.shape
# Out:
# (373, 242)

# %%
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 2  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 3  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 4  1400000US06085500400  Census Tract 5004, Santa Clara County, California
#
#                                   S2301_C01_001E  \
# 0  Total!!Estimate!!Population 16 years and over
# 1                                           4796
# 2                                           5092
# 3                                           3264
# 4                                           1932
#
#                                       S2301_C01_001M  \
# 0  Total!!Margin of Error!!Population 16 years an...
# 1                                                540
# ...

# %%
#Checking for number of columns
data2010ACSEmploymentCensusTract.columns
# Out:
# Index(['GEO_ID', 'NAME', 'S2301_C01_001E', 'S2301_C01_001M', 'S2301_C02_001E',
#        'S2301_C02_001M', 'S2301_C03_001E', 'S2301_C03_001M', 'S2301_C04_001E',
#        'S2301_C04_001M',
#        ...
#        'S2301_C04_029E', 'S2301_C04_029M', 'S2301_C01_030E', 'S2301_C01_030M',
#        'S2301_C02_030E', 'S2301_C02_030M', 'S2301_C03_030E', 'S2301_C03_030M',
#        'S2301_C04_030E', 'S2301_C04_030M'],
#       dtype='object', length=242)

# %%
#Rename the column "NAME" to "NAMESLSAD10"
data2010ACSEmploymentCensusTract.rename(columns={"NAME":"NAMESLSAD10"}, inplace=True)

# %%
# Confirm the change
data2010ACSEmploymentCensusTract.columns
# Out:
# Index(['GEO_ID', 'NAMESLSAD10', 'S2301_C01_001E', 'S2301_C01_001M',
#        'S2301_C02_001E', 'S2301_C02_001M', 'S2301_C03_001E', 'S2301_C03_001M',
#        'S2301_C04_001E', 'S2301_C04_001M',
#        ...
#        'S2301_C04_029E', 'S2301_C04_029M', 'S2301_C01_030E', 'S2301_C01_030M',
#        'S2301_C02_030E', 'S2301_C02_030M', 'S2301_C03_030E', 'S2301_C03_030M',
#        'S2301_C04_030E', 'S2301_C04_030M'],
#       dtype='object', length=242)

# %%
#To check for the mssing values
data2010ACSEmploymentCensusTract.isnull().sum()
# Out:
# GEO_ID            0
# NAMESLSAD10       0
# S2301_C01_001E    0
# S2301_C01_001M    0
# S2301_C02_001E    0
#                  ..
# S2301_C02_030M    0
# S2301_C03_030E    0
# S2301_C03_030M    0
# S2301_C04_030E    0
# S2301_C04_030M    0
# Length: 242, dtype: int64

# %%
#
data2010ACSEmploymentCensusTract.head()
# Out:
#                  GEO_ID                                        NAMESLSAD10  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06085500100  Census Tract 5001, Santa Clara County, California
# 2  1400000US06085500200  Census Tract 5002, Santa Clara County, California
# 3  1400000US06085500300  Census Tract 5003, Santa Clara County, California
# 4  1400000US06085500400  Census Tract 5004, Santa Clara County, California
#
#                                   S2301_C01_001E  \
# 0  Total!!Estimate!!Population 16 years and over
# 1                                           4796
# 2                                           5092
# 3                                           3264
# 4                                           1932
#
#                                       S2301_C01_001M  \
# 0  Total!!Margin of Error!!Population 16 years an...
# 1                                                540
# ...
