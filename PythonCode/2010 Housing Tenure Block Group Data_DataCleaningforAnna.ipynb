# %%
import pandas as pd

# %%
DeccenialHousingTenure2010file = r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\DemoGraphicApplication\DecennialDataBlockGroups\HousingTenure2010BlockGroupDECENNIALSF12010.H16-Data.csv'

# %%
DeccenialHousingTenure2010 = pd.read_csv(DeccenialHousingTenure2010file)

# %%
DeccenialHousingTenure2010.shape
# Out:
# (1076, 20)

# %%
DeccenialHousingTenure2010.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US060855001001  Block Group 1, Census Tract 5001, Santa Clara ...
# 2  1500000US060855001002  Block Group 2, Census Tract 5001, Santa Clara ...
# 3  1500000US060855001003  Block Group 3, Census Tract 5001, Santa Clara ...
# 4  1500000US060855001004  Block Group 4, Census Tract 5001, Santa Clara ...
#
#   H016001                H016002                                    H016003  \
# 0   Total  Total!!Owner occupied  Total!!Owner occupied!!1-person household
# 1     297                     73                                         20
# 2     423                    205                                         46
# 3     538                    219                                         55
# 4     820                    386                                        122
#
#                                      H016004  \
# ...

# %%
DeccenialHousingTenure = pd.read_csv(DeccenialHousingTenure2010file, skiprows=[1])

# %%
DeccenialHousingTenure.shape
# Out:
# (1075, 20)

# %%
for col in DeccenialHousingTenure.columns:
    print(col)
# Out:
# GEO_ID
# NAME
# H016001
# H016002
# H016003
# H016004
# H016005
# H016006
# H016007
# H016008
# H016009
# H016010
# H016011
# H016012
# H016013
# H016014
# H016015
# H016016
# H016017
# Unnamed: 19

# %%
DeccenialHousingTenure2010_cleaned = DeccenialHousingTenure.drop(columns=[col for col in DeccenialHousingTenure.columns if 'Unnamed: 19' in col])

# %%
DeccenialHousingTenure2010_cleaned.shape
# Out:
# (1075, 19)

# %%
for col in DeccenialHousingTenure2010_cleaned.columns:
    print(col)
# Out:
# GEO_ID
# NAME
# H016001
# H016002
# H016003
# H016004
# H016005
# H016006
# H016007
# H016008
# H016009
# H016010
# H016011
# H016012
# H016013
# H016014
# H016015
# H016016
# H016017

# %%
DeccenialHousingTenure2010_cleaned.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0  1500000US060855001001  Block Group 1, Census Tract 5001, Santa Clara ...
# 1  1500000US060855001002  Block Group 2, Census Tract 5001, Santa Clara ...
# 2  1500000US060855001003  Block Group 3, Census Tract 5001, Santa Clara ...
# 3  1500000US060855001004  Block Group 4, Census Tract 5001, Santa Clara ...
# 4  1500000US060855002001  Block Group 1, Census Tract 5002, Santa Clara ...
#
#    H016001  H016002  H016003  H016004  H016005  H016006  H016007  H016008  \
# 0      297       73       20       16       12        9        7        3
# 1      423      205       46       59       40       34       13        8
# 2      538      219       55       55       36       25       26       11
# 3      820      386      122      122       62       39       10       14
# 4      491      162       49       49       31       20        6        4
#
# ...

# %%
#Checking for number of columns
DeccenialHousingTenure2010_cleaned.columns
# Out:
# Index(['GEO_ID', 'NAME', 'H016001', 'H016002', 'H016003', 'H016004', 'H016005',
#        'H016006', 'H016007', 'H016008', 'H016009', 'H016010', 'H016011',
#        'H016012', 'H016013', 'H016014', 'H016015', 'H016016', 'H016017'],
#       dtype='object')

# %%
DeccenialHousingTenure2010_cleaned.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0  1500000US060855001001  Block Group 1, Census Tract 5001, Santa Clara ...
# 1  1500000US060855001002  Block Group 2, Census Tract 5001, Santa Clara ...
# 2  1500000US060855001003  Block Group 3, Census Tract 5001, Santa Clara ...
# 3  1500000US060855001004  Block Group 4, Census Tract 5001, Santa Clara ...
# 4  1500000US060855002001  Block Group 1, Census Tract 5002, Santa Clara ...
#
#    H016001  H016002  H016003  H016004  H016005  H016006  H016007  H016008  \
# 0      297       73       20       16       12        9        7        3
# 1      423      205       46       59       40       34       13        8
# 2      538      219       55       55       36       25       26       11
# 3      820      386      122      122       62       39       10       14
# 4      491      162       49       49       31       20        6        4
#
# ...

# %%
DeccenialHousingTenure2010_cleaned.shape
# Out:
# (1075, 19)

# %%
# Split the string at each comma and retain only the first two parts
DeccenialHousingTenure2010_cleaned["NAME"] = DeccenialHousingTenure2010_cleaned["NAME"].str.split(',', n=2).str[:2].str.join(',')

# %%
DeccenialHousingTenure2010_cleaned.head()
# Out:
#                   GEO_ID                              NAME  H016001  H016002  \
# 0  1500000US060855001001  Block Group 1, Census Tract 5001      297       73
# 1  1500000US060855001002  Block Group 2, Census Tract 5001      423      205
# 2  1500000US060855001003  Block Group 3, Census Tract 5001      538      219
# 3  1500000US060855001004  Block Group 4, Census Tract 5001      820      386
# 4  1500000US060855002001  Block Group 1, Census Tract 5002      491      162
#
#    H016003  H016004  H016005  H016006  H016007  H016008  H016009  H016010  \
# 0       20       16       12        9        7        3        6      224
# 1       46       59       40       34       13        8        5      218
# 2       55       55       36       25       26       11       11      319
# 3      122      122       62       39       10       14       17      434
# 4       49       49       31       20        6        4        3      329
#
# ...

# %%
# Remove the '1500000US' from the specified column
DeccenialHousingTenure2010_cleaned['GEO_ID'] = DeccenialHousingTenure2010_cleaned['GEO_ID'].str.replace('1500000US', '', regex=False)

# %%
print(DeccenialHousingTenure2010_cleaned)
# Out:
#             GEO_ID                                 NAME  H016001  H016002  \
# 0     060855001001     Block Group 1, Census Tract 5001      297       73
# 1     060855001002     Block Group 2, Census Tract 5001      423      205
# 2     060855001003     Block Group 3, Census Tract 5001      538      219
# 3     060855001004     Block Group 4, Census Tract 5001      820      386
# 4     060855002001     Block Group 1, Census Tract 5002      491      162
# ...            ...                                  ...      ...      ...
# 1070  060855126043  Block Group 3, Census Tract 5126.04      178       62
# 1071  060855130001     Block Group 1, Census Tract 5130     1133        3
# 1072  060855130002     Block Group 2, Census Tract 5130      813        0
# 1073  060855130003     Block Group 3, Census Tract 5130     1000        1
# 1074  060855135001     Block Group 1, Census Tract 5135      381      239
#
#       H016003  H016004  H016005  H016006  H016007  H016008  H016009  H016010  \
# ...

# %%
DeccenialHousingTenure2010_cleaned.head()
# Out:
#          GEO_ID                              NAME  H016001  H016002  H016003  \
# 0  060855001001  Block Group 1, Census Tract 5001      297       73       20
# 1  060855001002  Block Group 2, Census Tract 5001      423      205       46
# 2  060855001003  Block Group 3, Census Tract 5001      538      219       55
# 3  060855001004  Block Group 4, Census Tract 5001      820      386      122
# 4  060855002001  Block Group 1, Census Tract 5002      491      162       49
#
#    H016004  H016005  H016006  H016007  H016008  H016009  H016010  H016011  \
# 0       16       12        9        7        3        6      224       49
# 1       59       40       34       13        8        5      218       35
# 2       55       36       25       26       11       11      319       22
# 3      122       62       39       10       14       17      434      132
# 4       49       31       20        6        4        3      329      169
#
#    H016012  H016013  H016014  H016015  H016016  H016017
# ...

# %%
# Assuming your DataFrame is named df and the column is 'GEO_ID'
DeccenialHousingTenure2010_cleaned['GEO_ID'] = DeccenialHousingTenure2010_cleaned['GEO_ID'].astype(str).str.zfill(12)

# %%
DeccenialHousingTenure2010_cleaned.shape
# Out:
# (1075, 19)

# %%
DeccenialHousingTenure2010_cleaned.head()
# Out:
#          GEO_ID                              NAME  H016001  H016002  H016003  \
# 0  060855001001  Block Group 1, Census Tract 5001      297       73       20
# 1  060855001002  Block Group 2, Census Tract 5001      423      205       46
# 2  060855001003  Block Group 3, Census Tract 5001      538      219       55
# 3  060855001004  Block Group 4, Census Tract 5001      820      386      122
# 4  060855002001  Block Group 1, Census Tract 5002      491      162       49
#
#    H016004  H016005  H016006  H016007  H016008  H016009  H016010  H016011  \
# 0       16       12        9        7        3        6      224       49
# 1       59       40       34       13        8        5      218       35
# 2       55       36       25       26       11       11      319       22
# 3      122       62       39       10       14       17      434      132
# 4       49       31       20        6        4        3      329      169
#
#    H016012  H016013  H016014  H016015  H016016  H016017
# ...

# %%
DeccenialHousingTenure2010_cleaned.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\DemoGraphicApplication\DecennialDataBlockGroups\2010_HousingTenure_BlockGroup_Data_CLEANVersion.csv')

# %%
# Assuming your DataFrame is named df and the column is 'GEO_ID'
DeccenialHousingTenure2010_cleaned['GEO_ID'] = DeccenialHousingTenure2010_cleaned['GEO_ID'].astype(str).str.zfill(12)  # Adjust the number inside zfill to match the length you need

# %%
DeccenialHousingTenure2010_cleaned.to_csv(r'D:\VaibhavsPersonal\Fall2024\URBP-279\ClientProject\Data\DemoGraphicApplication\DecennialDataBlockGroups\2010_HousingTenure_BlockGroup_Data_CLEANVersion2.csv')
